# %%
colour_1="red"

# %%
colour_1
# Out:
# 'red'

# %%
print("the colour name is", colour_1)
# Out:
# the colour name is red

# %%
type(colour_1)
# Out:
# str

# %%
colour_2="blue"

# %%
colour_2
# Out:
# 'blue'

# %%
print("the colour name is", colour_2)
# Out:
# the colour name is blue

# %%
type(colour_2)
# Out:
# str

# %%
colour_3="green"

# %%
colour_3
# Out:
# 'green'

# %%
print("the colour name is", colour_3)
# Out:
# the colour name is green

# %%
type(colour_3)
# Out:
# str

# %%
colour_4="yellow"

# %%
colour_4
# Out:
# 'yellow'

# %%
print("the colour name is", colour_4)
# Out:
# the colour name is yellow

# %%
type(colour_4)
# Out:
# str

# %%
colour_5="orange"

# %%
colour_5
# Out:
# 'orange'

# %%
print("the colour name is" , colour_5)
# Out:
# the colour name is orange

# %%
type(colour_5)
# Out:
# str

# %%
colour_6="purple"

# %%
colour_6
# Out:
# 'purple'

# %%
print("the colour name is" , colour_6)
# Out:
# the colour name is purple

# %%
type(colour_6)
# Out:
# str

# %%
colour_7="pink"

# %%
colour_7
# Out:
# 'pink'

# %%
print("the colour name is" , colour_7)
# Out:
# the colour name is pink

# %%
type(colour_7)
# Out:
# str

# %%
colour_8="black"

# %%
colour_8
# Out:
# 'black'

# %%
print("the colour name is" , colour_8)
# Out:
# the colour name is black

# %%
type(colour_8)
# Out:
# str

# %%
colour_9="white"

# %%
colour_9
# Out:
# 'white'

# %%
print("the colour name is" , colour_9)
# Out:
# the colour name is white

# %%
type(colour_9)
# Out:
# str

# %%
colour_10="brown"

# %%
colour_10
# Out:
# 'brown'

# %%
print("the colour name is" , colour_10)
# Out:
# the colour name is brown

# %%
type(colour_10)
# Out:
# str
