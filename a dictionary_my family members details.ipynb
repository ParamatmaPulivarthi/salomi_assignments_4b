# %%
family_members={
    "jayapaul":{"relation":"father","qul":"degree","location":"nidumolu"},
    "ranga_sarojini":{"relation":"mother","qul":"degree","location":"nidumolu"},
    "rajakumari":{"relation":"eldest_sister","qul":"b.tech","location":"kandrika"},
    "sunilraju":{"relation":"brother","qul":"b.tech","location":"nidumolu"},
    "sowjannya":{"relation":"middlesister","qul":"b.tech","location":"movva"},
    "anilkumar":{"relation":"brother_in_law","qul":"dipolma","location":"movva"},
    "venkataramanayya":{"relation":"brothe_in_laww","qul":"mlt","location":"kandrika"},
    "meghana":{"relation":"sister_in_law","qul":"degree","location":"nidumolu"},
    "subramanyeswararao":{"relation":"uncle","qul":"intermediate","location":"nidumolu"},
    "venkateswararao":{"relation":"maternaluncle","qul":"7th class","location":"movva"}
}

# %%
family_members
# Out:
# {'jayapaul': {'relation': 'father', 'qul': 'degree', 'location': 'nidumolu'},
#  'ranga_sarojini': {'relation': 'mother',
#   'qul': 'degree',
#   'location': 'nidumolu'},
#  'rajakumari': {'relation': 'eldest_sister',
#   'qul': 'b.tech',
#   'location': 'kandrika'},
#  'sunilraju': {'relation': 'brother', 'qul': 'b.tech', 'location': 'nidumolu'},
#  'sowjannya': {'relation': 'middlesister',
#   'qul': 'b.tech',
#   'location': 'movva'},
#  'anilkumar': {'relation': 'brother_in_law',
#   'qul': 'dipolma',
#   'location': 'movva'},
#  'venkataramanayya': {'relation': 'brothe_in_laww',
#   'qul': 'mlt',
#   'location': 'kandrika'},
#  'meghana': {'relation': 'sister_in_law',
#   'qul': 'degree',
#   'location': 'nidumolu'},
#  'subramanyeswararao': {'relation': 'uncle',
#   'qul': 'intermediate',
#   'location': 'nidumolu'},
#  'venkateswararao': {'relation': 'maternaluncle',
#   'qul': '7th class',
#   'location': 'movva'}}

# %%
print(family_members)
# Out:
# {'jayapaul': {'relation': 'father', 'qul': 'degree', 'location': 'nidumolu'}, 'ranga_sarojini': {'relation': 'mother', 'qul': 'degree', 'location': 'nidumolu'}, 'rajakumari': {'relation': 'eldest_sister', 'qul': 'b.tech', 'location': 'kandrika'}, 'sunilraju': {'relation': 'brother', 'qul': 'b.tech', 'location': 'nidumolu'}, 'sowjannya': {'relation': 'middlesister', 'qul': 'b.tech', 'location': 'movva'}, 'anilkumar': {'relation': 'brother_in_law', 'qul': 'dipolma', 'location': 'movva'}, 'venkataramanayya': {'relation': 'brothe_in_laww', 'qul': 'mlt', 'location': 'kandrika'}, 'meghana': {'relation': 'sister_in_law', 'qul': 'degree', 'location': 'nidumolu'}, 'subramanyeswararao': {'relation': 'uncle', 'qul': 'intermediate', 'location': 'nidumolu'}, 'venkateswararao': {'relation': 'maternaluncle', 'qul': '7th class', 'location': 'movva'}}

# %%
type(family_members)
# Out:
# dict
