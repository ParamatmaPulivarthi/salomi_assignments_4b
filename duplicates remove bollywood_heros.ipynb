# %%
# this is a duplicates remove bollywood_ heros names program

# %%
bollywood_heros=["sharukkhan","salmankhan","salmankhan","amirkhan","HrithikRoshan","AmitabhBachchan","AkshayKumar","amirkhan"]

# %%
bollywood_heros
# Out:
# ['sharukkhan',
#  'salmankhan',
#  'salmankhan',
#  'amirkhan',
#  'HrithikRoshan',
#  'AmitabhBachchan',
#  'AkshayKumar',
#  'amirkhan']

# %%
duplicates remove

# %%
bollywood_heros_v1=set(bollywood_heros)

# %%
bollywood_heros_v1
# Out:
# {'AkshayKumar',
#  'AmitabhBachchan',
#  'HrithikRoshan',
#  'amirkhan',
#  'salmankhan',
#  'sharukkhan'}
