# %%
family_members_details={
    "family_members":{"jayapaul":"father",
                      "rangasarojini":"mother",
                      "rajakumari":"eldest_sister",
                      "venkataramanayya":"brother_in_law",
                      "sunilraju":"brother",
                      "meghana":"sister_in_law",
                      "sowjanya":"middlesister",
                      "anilkumar":"brother_in_law",
                      "subramanyeswararao":"uncle",
                      "venkateswararao":"maternaluncle"
                     },
                      "relations":{
                      "father":"jayapaul",
                       "mother":"rangasarojini",
                       "eldest_sister":"rajakumari",
                       "brother_in_law":"venkataramanayya",   
                       "brother":"sunilraju",
                       "sister_in_law":"meghana",
                       "middlesister":"sowjanya",
                       "brother_in_law":"anilkumar", 
                       "uncle":"subramanyeswararao",
                       "maternaluncle":"venkateswararao"}
                      }

# %%
print(family_members_details)
# Out:
# {'family_members': {'jayapaul': 'father', 'rangasarojini': 'mother', 'rajakumari': 'eldest_sister', 'venkataramanayya': 'brother_in_law', 'sunilraju': 'brother', 'meghana': 'sister_in_law', 'sowjanya': 'middlesister', 'anilkumar': 'brother_in_law', 'subramanyeswararao': 'uncle', 'venkateswararao': 'maternaluncle'}, 'relations': {'father': 'jayapaul', 'mother': 'rangasarojini', 'eldest_sister': 'rajakumari', 'brother_in_law': 'anilkumar', 'brother': 'sunilraju', 'sister_in_law': 'meghana', 'middlesister': 'sowjanya', 'uncle': 'subramanyeswararao', 'maternaluncle': 'venkateswararao'}}

# %%
family_members_details ["family_members"]["jayapaul"]
# Out:
# 'father'

# %%
family_members_details ["relations"]["father"]
# Out:
# 'jayapaul'

# %%
print("my father name is",family_members_details ["relations"]["father"])
# Out:
# my father name is jayapaul

# %%
print("my favorite family member name is",family_members_details ["relations"]["brother"])
# Out:
# my favorite family member name is sunilraju
