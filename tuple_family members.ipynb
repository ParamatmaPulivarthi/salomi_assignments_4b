# %%
family_members=("father" ,"mother" , "eldest sister" , "brother" , "middle sister" , "brother in law" , "niece" , "sister in law" , "nephew" , "maternal uncle")

# %%
family_members
# Out:
# ('father',
#  'mother',
#  'eldest sister',
#  'brother',
#  'middle sister',
#  'brother in law',
#  'niece',
#  'sister in law',
#  'nephew',
#  'maternal uncle')

# %%
family_members[0]
# Out:
# 'father'

# %%
family_members[1]
# Out:
# 'mother'

# %%
family_members[2]
# Out:
# 'eldest sister'

# %%
family_members[3]
# Out:
# 'brother'

# %%
family_members[4]
# Out:
# 'middle sister'

# %%
family_members[5]
# Out:
# 'brother in law'

# %%
family_members[7]
# Out:
# 'sister in law'

# %%
family_members[8]
# Out:
# 'nephew'

# %%
family_members[9]
# Out:
# 'maternal uncle'

# %%
family_members[-1]
# Out:
# 'maternal uncle'

# %%
family_members[-2]
# Out:
# 'nephew'

# %%
family_members[-3]
# Out:
# 'sister in law'

# %%
family_members[-4]
# Out:
# 'niece'

# %%
family_members[-5]
# Out:
# 'brother in law'

# %%
family_members[-6]
# Out:
# 'middle sister'

# %%
family_members[-7]
# Out:
# 'brother'

# %%
family_members[-8]
# Out:
# 'eldest sister'

# %%
family_members[-9]
# Out:
# 'mother'

# %%
family_members[0]
# Out:
# 'father'

# %%
family_members[1:3]
# Out:
# ('mother', 'eldest sister')

# %%
family_members[:3]
# Out:
# ('father', 'mother', 'eldest sister')

# %%
family_members[4:7]
# Out:
# ('middle sister', 'brother in law', 'niece')

# %%
family_members[:7]
# Out:
# ('father',
#  'mother',
#  'eldest sister',
#  'brother',
#  'middle sister',
#  'brother in law',
#  'niece')

# %%
family_members[-1:]
# Out:
# ('maternal uncle',)

# %%
family_members[8:10]
# Out:
# ('nephew', 'maternal uncle')

# %%
family_members[:10]
# Out:
# ('father',
#  'mother',
#  'eldest sister',
#  'brother',
#  'middle sister',
#  'brother in law',
#  'niece',
#  'sister in law',
#  'nephew',
#  'maternal uncle')
