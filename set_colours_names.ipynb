# %%
colour_names={"blue","yellow","red","orange","green","purple","brown","pink","black","white"}

# %%
colour_names
# Out:
# {'black',
#  'blue',
#  'brown',
#  'green',
#  'orange',
#  'pink',
#  'purple',
#  'red',
#  'white',
#  'yellow'}
