# %%
destination_cities_rating={
"destinations":[ 
 {"city":"paris","rating":7},
 {"city":"tokyo","rating":8},
 {"city":"london","rating":3},
 {"city":"dubai","rating":10},
 {"city":"balli","rating":8},
 {"city":"newyork","rating":9},
 {"city":"singapore","rating":8},
 {"city":"sydney","rating":10},
 {"city":"mumbai","rating":8},
 {"city":"rome","rating":9}
]
}

# %%
destination_cities_rating
# Out:
# {'destinations': [{'city': 'paris', 'rating': 7},
#   {'city': 'tokyo', 'rating': 8},
#   {'city': 'london', 'rating': 3},
#   {'city': 'dubai', 'rating': 10},
#   {'city': 'balli', 'rating': 8},
#   {'city': 'newyork', 'rating': 9},
#   {'city': 'singapore', 'rating': 8},
#   {'city': 'sydney', 'rating': 10},
#   {'city': 'mumbai', 'rating': 8},
#   {'city': 'rome', 'rating': 9}]}

# %%
print("rating 3 city name is","london")
# Out:
# rating 3 city name is london
