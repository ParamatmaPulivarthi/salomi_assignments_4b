# %%
father="jayapaul"

# %%
father
# Out:
# 'jayapaul'

# %%
print("my father name is", father)
# Out:
# my father name is jayapaul

# %%
type(father)
# Out:
# str

# %%
mother="ranga sarojini"

# %%
mother
# Out:
# 'ranga sarojini'

# %%
print("my mother name is" , mother)
# Out:
# my mother name is ranga sarojini

# %%
type(mother)
# Out:
# str

# %%
eldest_sister="rajakumari"

# %%
eldest_sister
# Out:
# 'rajakumari'

# %%
print("my elder sister name is", eldest_sister)
# Out:
# my elder sister name is rajakumari

# %%
type(eldest_sister)
# Out:
# str

# %%
brother="sunil raju"

# %%
brother
# Out:
# 'sunil raju'

# %%
print("my brother name is",brother)
# Out:
# my brother name is sunil raju

# %%
type(brother)
# Out:
# str

# %%
middle_sister="sowjanya"

# %%
middle_sister
# Out:
# 'sowjanya'

# %%
print("my middle_sister name is", middle_sister)
# Out:
# my middle_sister name is sowjanya

# %%
type(middle_sister)
# Out:
# str

# %%
brother_in_law="anil kumar"

# %%
brother_in_law
# Out:
# 'anil kumar'

# %%
print("my brother_in_law name is" , brother_in_law)
# Out:
# my brother_in_law name is anil kumar

# %%
type(brother_in_law)
# Out:
# str

# %%
niece="mahima"

# %%
niece
# Out:
# 'mahima'

# %%
print("my niece name is" ,niece)
# Out:
# my niece name is mahima

# %%
type(niece)
# Out:
# str

# %%
sister_in_law="meghana"

# %%
sister_in_law
# Out:
# 'meghana'

# %%
print("my sister_in_law name is", sister_in_law)
# Out:
# my sister_in_law name is meghana

# %%
type(sister_in_law)
# Out:
# str

# %%
nephew="yona francis"

# %%
nephew
# Out:
# 'yona francis'

# %%
print("my nephew name is", nephew)
# Out:
# my nephew name is yona francis

# %%
type(nephew)
# Out:
# str

# %%
maternal_uncle="venkateswararao"

# %%
maternal_uncle
# Out:
# 'venkateswararao'

# %%
print("my maternal_uncle name is" , maternal_uncle)
# Out:
# my maternal_uncle name is venkateswararao

# %%
type(maternal_uncle)
# Out:
# str
