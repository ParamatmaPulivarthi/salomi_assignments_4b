# %%
friend_qualities={"friend_names": ["maneesha","esterbi","sujana","meghana","pushpa","eliyazar","prakash","vani","vijaya","priyanka"],
    "quality":["creative","loyalty","honesty","intelligent","funny","hardworking","helpful","kindness","bravery","decent"]}

# %%
print(friend_qualities)
# Out:
# {'friend_names': ['maneesha', 'esterbi', 'sujana', 'meghana', 'pushpa', 'eliyazar', 'prakash', 'vani', 'vijaya', 'priyanka'], 'quality': ['creative', 'loyalty', 'honesty', 'intelligent', 'funny', 'hardworking', 'helpful', 'kindness', 'bravery', 'decent']}

# %%
intelligentfriend_name_v4="meghana"

# %%
print("my intelligent friend name is",intelligentfriend_name_v4)
# Out:
# my intelligent friend name is meghana

# %%
best_friend_v3="sujana"

# %%
print("my best friend name is",best_friend_v3)
# Out:
# my best friend name is sujana
