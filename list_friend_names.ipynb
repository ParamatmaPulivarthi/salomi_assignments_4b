# %%
friend_names=['maneesha' , 'priyanka', 'esterbi' , 'vani' , 'rani' , 'pushpa' , 'eliyazar' , 'nagalakshmi' , 'seetha' , 'pavan']

# %%
friend_names
# Out:
# ['maneesha',
#  'priyanka',
#  'esterbi',
#  'vani',
#  'rani',
#  'pushpa',
#  'eliyazar',
#  'nagalakshmi',
#  'seetha',
#  'pavan']

# %%
friend_names[0]
# Out:
# 'maneesha'

# %%
friend_names[1]
# Out:
# 'priyanka'

# %%
friend_names[2]
# Out:
# 'esterbi'

# %%
friend_names[3]
# Out:
# 'vani'

# %%
friend_names[4]
# Out:
# 'rani'

# %%
friend_names[5]
# Out:
# 'pushpa'

# %%
friend_names[6]
# Out:
# 'eliyazar'

# %%
friend_names[7]
# Out:
# 'nagalakshmi'

# %%
friend_names[8]
# Out:
# 'seetha'

# %%
friend_names[9]
# Out:
# 'pavan'

# %%
friend_names[-1]
# Out:
# 'pavan'

# %%
friend_names[-2]
# Out:
# 'seetha'

# %%
friend_names[-3]
# Out:
# 'nagalakshmi'

# %%
friend_names[-4]
# Out:
# 'eliyazar'

# %%
friend_names[-5]
# Out:
# 'pushpa'

# %%
friend_names[-6]
# Out:
# 'rani'

# %%
friend_names[-7]
# Out:
# 'vani'

# %%
friend_names[-8]
# Out:
# 'esterbi'

# %%
friend_names[-9]
# Out:
# 'priyanka'

# %%
friend_names[0]
# Out:
# 'maneesha'

# %%
friend_names[1:3]
# Out:
# ['priyanka', 'esterbi']

# %%
friend_names[:3]
# Out:
# ['maneesha', 'priyanka', 'esterbi']

# %%
friend_names[4:7]
# Out:
# ['rani', 'pushpa', 'eliyazar']

# %%
friend_names[:7]
# Out:
# ['maneesha', 'priyanka', 'esterbi', 'vani', 'rani', 'pushpa', 'eliyazar']

# %%
friend_names[6:10]
# Out:
# ['eliyazar', 'nagalakshmi', 'seetha', 'pavan']

# %%
friend_names[:10]
# Out:
# ['maneesha',
#  'priyanka',
#  'esterbi',
#  'vani',
#  'rani',
#  'pushpa',
#  'eliyazar',
#  'nagalakshmi',
#  'seetha',
#  'pavan']
