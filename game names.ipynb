# %%
game_1="cricket"

# %%
game_1
# Out:
# 'cricket'

# %%
print("the game name is" , game_1)
# Out:
# the game name is cricket

# %%
type(game_1)
# Out:
# str

# %%
game_2="kabaddi"

# %%
game_2
# Out:
# 'kabaddi'

# %%
print("the game name is" , game_2)
# Out:
# the game name is kabaddi

# %%
type(game_2)
# Out:
# str

# %%
game_3="ludo king"

# %%
game_3
# Out:
# 'ludo king'

# %%
print("the game name is" , game_3)
# Out:
# the game name is ludo king

# %%
type(game_3)
# Out:
# str

# %%
game_4="battlegrounds mobile india"

# %%
game_4
# Out:
# 'battlegrounds mobile india'

# %%
print("the game name is" , game_4)
# Out:
# the game name is battlegrounds mobile india

# %%
type(game_4)
# Out:
# str

# %%
game_5="chess"

# %%
game_5
# Out:
# 'chess'

# %%
print("the game name is" , game_5)
# Out:
# the game name is chess

# %%
type(game_5)
# Out:
# str

# %%
game_6="kho_kho"

# %%
game_6
# Out:
# 'kho_kho'

# %%
print("the game name is" , game_6)
# Out:
# the game name is kho_kho

# %%
type(game_6)
# Out:
# str

# %%
game_7="carrom"

# %%
game_7
# Out:
# 'carrom'

# %%
print("the game name is" , game_7)
# Out:
# the game name is carrom

# %%
type(game_7)
# Out:
# str

# %%
game_8="gilli danda"

# %%
game_8
# Out:
# 'gilli danda'

# %%
print("the game name is" , game_8)
# Out:
# the game name is gilli danda

# %%
type(game_8)
# Out:
# str

# %%
game_9="football"

# %%
game_9
# Out:
# 'football'

# %%
print("the game name is" , game_9)
# Out:
# the game name is football

# %%
type(game_9)
# Out:
# str

# %%
game_10="free fire"

# %%
game_10
# Out:
# 'free fire'

# %%
print("the game name is" , game_10)
# Out:
# the game name is free fire

# %%
type(game_10)
# Out:
# str
