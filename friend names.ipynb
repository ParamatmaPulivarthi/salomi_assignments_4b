# %%
friend_1="maneesha"

# %%
friend_1
# Out:
# 'maneesha'

# %%
print(" the friend name is ", friend_1)
# Out:
#  the friend name is  maneesha

# %%
type(friend_1)
# Out:
# str

# %%
friend_2="priyanka"

# %%
friend_2
# Out:
# 'priyanka'

# %%
print(" the friend name is ", friend_2)
# Out:
#  the friend name is  priyanka

# %%
type(friend_2)
# Out:
# str

# %%
friend_3="esterbi"

# %%
friend_3
# Out:
# 'esterbi'

# %%
print("the friend name is", friend_3)
# Out:
# the friend name is esterbi

# %%
type(friend_3)
# Out:
# str

# %%
friend_4="vani"

# %%
friend_4
# Out:
# 'vani'

# %%
print("the friend name is", friend_4)
# Out:
# the friend name is vani

# %%
type(friend_4)
# Out:
# str

# %%
friend_5="rani"

# %%
friend_5
# Out:
# 'rani'

# %%
print("the friend name is", friend_5)
# Out:
# the friend name is rani

# %%
type(friend_5)
# Out:
# str

# %%
friend_6="pushpa"

# %%
friend_6
# Out:
# 'pushpa'

# %%
print("the friend name is", friend_6)
# Out:
# the friend name is pushpa

# %%
type(friend_6)
# Out:
# str

# %%
friend_7="eliyazar"

# %%
friend_7
# Out:
# 'eliyazar'

# %%
print("the friend name is", friend_7)
# Out:
# the friend name is eliyazar

# %%
type(friend_7)
# Out:
# str

# %%
friend_8="nagalakshmi"

# %%
friend_8
# Out:
# 'nagalakshmi'

# %%
print("the friend name is", friend_8)
# Out:
# the friend name is nagalakshmi

# %%
type(friend_8)
# Out:
# str

# %%
friend_9="seetha"

# %%
friend_9
# Out:
# 'seetha'

# %%
print("the friend name is", friend_9)
# Out:
# the friend name is seetha

# %%
type(friend_9)
# Out:
# str

# %%
friend_10="pavan"

# %%
friend_10
# Out:
# 'pavan'

# %%
print("the friend name is", friend_10)
# Out:
# the friend name is pavan

# %%
type(friend_10)
# Out:
# str
