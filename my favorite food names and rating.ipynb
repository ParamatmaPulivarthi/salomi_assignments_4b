# %%
food_ratings={
    "veg_items":{"brinjalfry":3,
                 "aratikaya vepudu":4,
                 "dosakaya pappu":5,
                 "majjiga pulusu":1,
                 "idli":2,
                 "dosa":5,
                 "sambar":4,
                 "lemon rice":3,
                 "vada":2,
                 "potatofry":5},
    "nonveg_items":{"chickenfry":1,
                    "prawnscurry":4,
                    "fishfry":5,
                    "chickenfriedrice":3,
                    "gongurachicken":2,
                    "crabcurry":5,
                    "chickenpakodi":4,
                    "chickenbiryani":3,
                    "eggfriedrice":5,
                    "chickenliverfry":4}
}

# %%
food_ratings
# Out:
# {'veg_items': {'brinjalfry': 3,
#   'aratikaya vepudu': 4,
#   'dosakaya pappu': 5,
#   'majjiga pulusu': 1,
#   'idli': 2,
#   'dosa': 5,
#   'sambar': 4,
#   'lemon rice': 3,
#   'vada': 2,
#   'potatofry': 5},
#  'nonveg_items': {'chickenfry': 1,
#   'prawnscurry': 4,
#   'fishfry': 5,
#   'chickenfriedrice': 3,
#   'gongurachicken': 2,
#   'crabcurry': 5,
#   'chickenpakodi': 4,
#   'chickenbiryani': 3,
#   'eggfriedrice': 5,
#   'chickenliverfry': 4}}

# %%
rating1="chickenfry"

# %%
print("rating 1 food name is",rating1)
# Out:
# rating 1 food name is chickenfry
