# %%
food_1="chicken_biryani"

# %%
food_1
# Out:
# 'chicken_biryani'

# %%
print("the food name is", food_1)
# Out:
# the food name is chicken_biryani

# %%
type(food_1)
# Out:
# str

# %%
food_2="panipuri"

# %%
food_2
# Out:
# 'panipuri'

# %%
print("the food name is", food_2)
# Out:
# the food name is panipuri

# %%
type(food_2)
# Out:
# str

# %%
food_3="masala dosa"

# %%
food_3
# Out:
# 'masala dosa'

# %%
print("the food name is",food_3)
# Out:
# the food name is masala dosa

# %%
type(food_3)
# Out:
# str

# %%
food_4="idli and sambar"

# %%
food_4
# Out:
# 'idli and sambar'

# %%
print("the food name is", food_4)
# Out:
# the food name is idli and sambar

# %%
type(food_4)
# Out:
# str

# %%
food_5="gulab jamun"

# %%
food_5
# Out:
# 'gulab jamun'

# %%
print("the food name is", food_5)
# Out:
# the food name is gulab jamun

# %%
type(food_5)
# Out:
# str

# %%
food_6="chicken fried rice"

# %%
food_6
# Out:
# 'chicken fried rice'

# %%
print("the food name is " , food_6)
# Out:
# the food name is  chicken fried rice

# %%
type(food_6)
# Out:
# str

# %%
food_7="fish fry"

# %%
food_7
# Out:
# 'fish fry'

# %%
print("the food name is", food_7)
# Out:
# the food name is fish fry

# %%
type(food_7)
# Out:
# str

# %%
food_8="egg bondas"

# %%
food_8
# Out:
# 'egg bondas'

# %%
print("the food name is", food_8)
# Out:
# the food name is egg bondas

# %%
type(food_8)
# Out:
# str

# %%
food_9="prawns fry"

# %%
food_9
# Out:
# 'prawns fry'

# %%
print("the food name is", food_9)
# Out:
# the food name is prawns fry

# %%
type(food_9)
# Out:
# str

# %%
food_10="egg curry"

# %%
food_10
# Out:
# 'egg curry'

# %%
print("the food name is", food_10)
# Out:
# the food name is egg curry

# %%
type(food_10)
# Out:
# str
