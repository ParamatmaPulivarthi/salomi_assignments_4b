# %%
month_1="january"

# %%
month_1
# Out:
# 'january'

# %%
print("this month name is" , month_1)
# Out:
# this month name is january

# %%
type(month_1)
# Out:
# str

# %%
month_2="february"

# %%
month_2
# Out:
# 'february'

# %%
print("this month name is" , month_2)
# Out:
# this month name is february

# %%
type(month_2)
# Out:
# str

# %%
month_3="march"

# %%
month_3
# Out:
# 'march'

# %%
print("this month name is" , month_3)
# Out:
# this month name is march

# %%
type(month_3)
# Out:
# str

# %%
month_4="april"

# %%
month_4
# Out:
# 'april'

# %%
print("this month name is" , month_4)
# Out:
# this month name is april

# %%
type(month_4)
# Out:
# str

# %%
month_5="may"

# %%
month_5
# Out:
# 'may'

# %%
print("this month name is" , month_5)
# Out:
# this month name is may

# %%
type(month_5)
# Out:
# str

# %%
month_6="june"

# %%
month_6
# Out:
# 'june'

# %%
print("this month name is" , month_6)
# Out:
# this month name is june

# %%
type(month_6)
# Out:
# str

# %%
month_7="july"

# %%
month_7
# Out:
# 'july'

# %%
print("this month name is" , month_7)
# Out:
# this month name is july

# %%
type(month_7)
# Out:
# str

# %%
month_8="august"

# %%
month_8
# Out:
# 'august'

# %%
print("this month name is" , month_8)
# Out:
# this month name is august

# %%
type(month_8)
# Out:
# str

# %%
month_9="september"

# %%
month_9
# Out:
# 'september'

# %%
print("this month name is" , month_9)
# Out:
# this month name is september

# %%
type(month_9)
# Out:
# str

# %%
month_10="october"

# %%
month_10
# Out:
# 'october'

# %%
print("this month name is" , month_10)
# Out:
# this month name is october

# %%
type(month_10)
# Out:
# str

# %%
month_11="november"

# %%
month_11
# Out:
# 'november'

# %%
print("this month name is" , month_11)
# Out:
# this month name is november

# %%
type(month_11)
# Out:
# str

# %%
month_12="december"

# %%
month_12
# Out:
# 'december'

# %%
print("this month name is" , month_12)
# Out:
# this month name is december

# %%
type(month_12)
# Out:
# str
